# %%
import sqlite3

connection = sqlite3.connect('sample.db') # stablishing the connection with the database
cursor = connection.cursor() # setting our cursor

# %%
query = 'SELECT * FROM people'

for result in cursor.execute(query):
    print(result)
# Out:
# (1, 'Tammy', 'Maxwell')
# (2, 'Mike', 'Valdez')
# (3, 'Andrew', 'Pierce')
# (4, 'Stephanie', 'Johnson')
# (5, 'Shelby', 'Jones')
# (6, 'Zoe', 'Dixon')
# (7, 'Cynthia', 'Crosby')
# (8, 'Ian', 'Snyder')
# (9, 'Jamie', 'Watson')
# (10, 'Jordan', 'Moreno')
# (11, 'Wayne', 'Giles')
# (12, 'Cristina', 'Smith')
# (13, 'Catherine', 'Martin')
# (14, 'Marie', 'Bennett')
# (15, 'Brittney', 'Bishop')
# (16, 'Douglas', 'Osborne')
# (17, 'Anna', 'Rice')
# (18, 'Rebecca', 'Hogan')
# (19, 'Richard', 'Garcia')
# (20, 'Melanie', 'Ryan')
# (21, 'Robert', 'Perez')
# (22, 'Joanna', 'Barajas')
# (23, 'Mary', 'Bates')
# (24, 'Zoe', 'Daniel')
# (25, 'Makayla', 'Butler')
# (26, 'Victor', 'Hines')
# (27, 'Ashley', 'Benton')
# (28, 'Diamond', 'Watkins')
# (29, 'Pamela', 'Rivera')
# (30, 'Karen', 'Moore')
# (31, 'Daniel', 'Walsh')
# (32, 'Edwin', 'Wells')
# (33, 'Carolyn', 'Saunders')
# (34, 'Julie', 'Ray')
# (35, 'Tyler', 'Moreno')
# (36, 'Margaret', 'Hood')
# (37, 'Robin', 'Turner')
# (38, 'Nancy', 'Hicks')
# ...
